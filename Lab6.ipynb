# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6e8266ab-b3f8-4588-af14-ff67df1fa539" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6e8266ab-b3f8-4588-af14-ff67df1fa539">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
 
df = pd.read_csv(io.BytesIO(uploaded['iris.csv']))
print(df)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **Data** **Analysis**

# %% [markdown]
# a. Load the iris dataset into a Pandas data frame and display the first 5 rows.

# %%
  df.head(5)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# b. Display the shape of the dataset (number of rows and columns).

# %%
  df.head(5)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# c. Display the summary statistics (mean, standard deviation, minimum, and maximum) for each
# column.

# %%
  df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# d. Create a new column in the data frame that is the product of the Sepal Length and Sepal Width columns.

# %%
# Create a new column
df['sepal.area'] = df['sepal.length'] * df['sepal.width']

df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety  sepal.area
# 0           5.1          3.5           1.4          0.2  Setosa       17.85
# 1           4.9          3.0           1.4          0.2  Setosa       14.70
# 2           4.7          3.2           1.3          0.2  Setosa       15.04
# 3           4.6          3.1           1.5          0.2  Setosa       14.26
# 4           5.0          3.6           1.4          0.2  Setosa       18.00

# %% [markdown]
# e. Display the unique values in the species column.

# %%
df['variety'].unique()
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %% [markdown]
# f. Create a scatterplot of the sepal length vs. sepal width columns, with different colours for each species.

# %%
# plotting a scatterplot 
sns.scatterplot(data=df, x='sepal.length',
                y='sepal.width', hue='variety')
plt.plot()
# Out:
# []
